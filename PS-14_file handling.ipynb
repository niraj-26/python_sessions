# %%
# connect chat gpt through python
# we connect maker suite

# %% [markdown]
# whever you want to read any file =>
# type of file
# - .txt
# - .csv       (comma seperted value)
# - .xlsx
# - .json      (dictionary format)
# - .xml       (Iot data)
# - .parquet   (encoded files)
# - .delta     (encoded files)
# - .pdf
# - .jpg
# - .png

# %% [markdown]
# - Where is your file location
# - what is file name
# - what is the type of file(extention)

# %%
# D:\notes DS
# mbox-short 40
# .txt

# %%
file_location="D:\notes DS"
file_name="mbox-short 40"
extention=".txt"

# %% [markdown]
# - Unicode Error : single slash
# - in order to read the file, we need provide '\\'

# %%
file_location+file_name+extention
# Out:
# 'D:\notes DSmbox-short 40.txt'

# %%
"D:\\notes DS\\mbox-short 40.txt"
# Out:
# 'D:\\notes DS\\mbox-short 40.txt'

# %%
file_path="D:\\notes DS\\mbox-short 40.txt"

# %%
open(file_path)
# mode: read/write
# emcoding: cp1252/utf-8
# Out:
# <_io.TextIOWrapper name='D:\\notes DS\\mbox-short 40.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# - Whenever any file has special character it will not read
# - that time you need to provide encoding value
# - different encoded files has different encoding method
# - 'cp1252/utf-8'  general example

# %%
file_path="D:\\notes DS\\mbox-short 40.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# # C35

# %%
# in the above case
# your data file and python file both are in different location
# ==> you need to provide full location 

# python  file and data file both are in same location
# you no need to provide the location
# file name+type(extention)

# %%
import os
os.getcwd()  # get current working directory
# Out:
# 'C:\\Users\\victus\\OneDrive\\jpnb by omkar'

# %%
# chatboat 20 file is present in jpnb by omkar

# %%
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
print(file.read())
# Out:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# ...

# %%
# change directory
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\victus\\OneDrive\\jpnb by omkar'

# %%
# change directory(location)
path="C:\\Users\\victus\\OneDrive\\Documents"
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\victus\\OneDrive\\Documents'

# %%
# if python and data file are in different location then you need to provide full location
# but in code you already changed the directory, where your data file existed
file_path='mbox-short_1.txt'   # mbox-short_1 is exist in documents
file=open(file_path,encoding='utf-8-sig')
print(file.read())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# - Hard code is there, this should be reduce
# - many lines are reduce singal lines or not
# - is yur file run at any place or not

# %% [markdown]
# $With$

# %%
file.read()
# Out:
# ''

# %%
file
# Out:
# <_io.TextIOWrapper name='mbox-short_1.txt' mode='r' encoding='utf-8-sig'>

# %%
# file_path='chatboat 20.txt'
# file=open(file_path,encoding='utf-8-sig')
# print(file.read())

file_path='chatboat 20.txt'
with open(file_path) as file:
    print(file.read())
# Out:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# ...

# %%
file_path="D:\\notes DS\\mbox-short 40.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
###############################
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
print(file.read())
################################
file_path='chatboat 20.txt'
with open(file_path) as file:
    data=file.read()
    print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
len(file_path)
# Out:
# 15

# %%
len(data)
# Out:
# 10377

# %%
#I want to get number of lines

# %% [markdown]
# $Enumerate$

# %%
for i in data:
    print(i)
# Out:
# D
# a
# t
# a
#
# s
# c
# i
# e
# n
# c
# e
#
# i
# s
#
# a
# n
#
# i
# n
# t
# e
# r
# d
# i
# s
# c
# i
# p
# l
# i
# n
# a
# r
# y
#
# a
# c
# a
# d
# e
# m
# i
# c
#
# f
# i
# e
# l
# d
# [
# 1
# ]
#
# t
# h
# a
# t
#
# u
# s
# e
# s
#
# s
# t
# a
# t
# i
# s
# t
# i
# c
# s
# ,
#
# s
# c
# i
# e
# n
# t
# i
# f
# i
# c
#
# c
# o
# m
# p
# u
# t
# i
# n
# g
# ,
#
# s
# c
# i
# e
# n
# t
# i
# f
# i
# c
#
# m
# e
# t
# h
# o
# d
# s
# ,
#
# p
# r
# o
# c
# e
# s
# s
# e
# s
# ,
#
# a
# l
# g
# o
# r
# i
# t
# h
# m
# s
#
# a
# n
# d
#
# s
# y
# s
# t
# e
# m
# s
#
# t
# o
#
# e
# x
# t
# r
# a
# c
# t
#
# o
# r
#
# e
# x
# t
# r
# a
# p
# o
# l
# a
# t
# e
#
# k
# n
# o
# w
# l
# e
# d
# g
# e
#
# a
# n
# d
#
# i
# n
# s
# i
# g
# h
# t
# s
#
# f
# r
# o
# m
#
# n
# o
# i
# s
# y
# ,
#
# s
# t
# r
# u
# c
# t
# u
# r
# e
# d
# ,
#
# a
# n
# d
#
# u
# n
# s
# t
# r
# u
# c
# t
# u
# r
# e
# d
#
# d
# a
# t
# a
# .
# [
# 2
# ]
#
#
#
#
# D
# a
# t
# a
#
# s
# c
# i
# e
# n
# c
# e
#
# ...

# %%
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
for i in file.read():
    print(i)  # characters will come
# Out:
# D
# a
# t
# a
#
# s
# c
# i
# e
# n
# c
# e
#
# i
# s
#
# a
# n
#
# i
# n
# t
# e
# r
# d
# i
# s
# c
# i
# p
# l
# i
# n
# a
# r
# y
#
# a
# c
# a
# d
# e
# m
# i
# c
#
# f
# i
# e
# l
# d
# [
# 1
# ]
#
# t
# h
# a
# t
#
# u
# s
# e
# s
#
# s
# t
# a
# t
# i
# s
# t
# i
# c
# s
# ,
#
# s
# c
# i
# e
# n
# t
# i
# f
# i
# c
#
# c
# o
# m
# p
# u
# t
# i
# n
# g
# ,
#
# s
# c
# i
# e
# n
# t
# i
# f
# i
# c
#
# m
# e
# t
# h
# o
# d
# s
# ,
#
# p
# r
# o
# c
# e
# s
# s
# e
# s
# ,
#
# a
# l
# g
# o
# r
# i
# t
# h
# m
# s
#
# a
# n
# d
#
# s
# y
# s
# t
# e
# m
# s
#
# t
# o
#
# e
# x
# t
# r
# a
# c
# t
#
# o
# r
#
# e
# x
# t
# r
# a
# p
# o
# l
# a
# t
# e
#
# k
# n
# o
# w
# l
# e
# d
# g
# e
#
# a
# n
# d
#
# i
# n
# s
# i
# g
# h
# t
# s
#
# f
# r
# o
# m
#
# n
# o
# i
# s
# y
# ,
#
# s
# t
# r
# u
# c
# t
# u
# r
# e
# d
# ,
#
# a
# n
# d
#
# u
# n
# s
# t
# r
# u
# c
# t
# u
# r
# e
# d
#
# d
# a
# t
# a
# .
# [
# 2
# ]
#
#
#
#
# D
# a
# t
# a
#
# s
# c
# i
# e
# n
# c
# e
#
# ...

# %%
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
for i in file:
    print(i)    # lines will come
# Out:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
#
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
#
#
# ...

# %% [markdown]
# - Before reading will have lines
# - if you want to see lines , work on file.read()
# - if you want to see the characters, work on file.read()

# %%
#Q1) get number of lines
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
count=0
for i in file:
    # print(i) 
    count+=1
print(count)
# Out:
# 45

# %%
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
for index,line in enumerate(file):
    print(index,line)
# Out:
# 0 Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
# 1
#
# 2 Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# 3
#
# ...

# %%
# enumerate give also index and file

# %%
# or
#methode-1
for index,lie in enumerate(file):
    pass

number=index+1
print(number)
# Out:
# 45

# %%
#methode-2
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
l1=len([index for index,_ in enumerate(file)])
l1
# here line are not required whenever you dont want use any specific variable keep that variable as_
# Out:
# 45

# %%
#Q3)  print first 10 lines
file_path='chatboat 20.txt'
file=open(file_path,encoding='utf-8-sig')
for index,line in enumerate(file):
    print(index,line)
    if index==10:
        break
# Out:
# 0 Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]
#
# 1
#
# 2 Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# 3
#
# ...

# %%
for index,line in enumerate(file):
    if index<10:
        print(index,line)
# Out:
# 0 Relationship to statistics
#
# 1 Many statisticians, including Nate Silver, have argued that data science is not a new field, but rather another name for statistics.[16] Others argue that data science is distinct from statistics because it focuses on problems and techniques unique to digital data.[17] Vasant Dhar writes that statistics emphasizes quantitative data and description. In contrast, data science deals with quantitative and qualitative data (e.g., from images, text, sensors, transactions, customer information, etc.) and emphasizes prediction and action.[18] Andrew Gelman of Columbia University has described statistics as a non-essential part of data science.[19]
#
# 2
#
# ...

# %%
# Q4) make all lines in same alignment
file_path='mbox-short 40.txt'
file=open(file_path,encoding='utf-8-sig')
for line in file:
    print(line.strip())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# ...

# %%
# Q5) Extract line those who are starting with "From"
# and kepp in a list
# and the count of list
file_path='mbox-short 40.txt'
file=open(file_path,encoding='utf-8-sig')

# for line in file:
#     if line.startswith('Data'):
#         print(line)
        
from_list=[line for line in file if line.startswith('From')]
len(from_list)
# Out:
# 54

# %%
from_list    # \n is in last line
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n',
#  'From: stephen.marquard@uct.ac.za\n',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008\n',
#  'From: louis@media.berkeley.edu\n',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008\n',
#  'From: zqian@umich.edu\n',
# ...

# %%
# Q6) remove '\n' from otput of above code
[line.rstrip('\n') for line in from_list]
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
#Q7) 5 and 6 with same
file_path='mbox-short 40.txt'
file=open(file_path,encoding='utf-8-sig')
from_list=[line.rstrip('\n') for line in file if line.startswith('From')]
from_list
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
# Q8) extract all emails from above output
str1='From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
print(str1.split()[1])
print(str1.split())
# Out:
# stephen.marquard@uct.ac.za
# ['From', 'stephen.marquard@uct.ac.za', 'Sat', 'Jan', '5', '09:14:16', '2008']

# %%
emails=[line.split()[1] for line in from_list]
emails
# Out:
# ['stephen.marquard@uct.ac.za',
#  'stephen.marquard@uct.ac.za',
#  'louis@media.berkeley.edu',
#  'louis@media.berkeley.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'rjlowe@iupui.edu',
#  'rjlowe@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'cwen@iupui.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'gsilver@umich.edu',
#  'gsilver@umich.edu',
#  'wagnermr@iupui.edu',
#  'wagnermr@iupui.edu',
#  'zqian@umich.edu',
#  'zqian@umich.edu',
#  'antranig@caret.cam.ac.uk',
#  'antranig@caret.cam.ac.uk',
#  'gopal.ramasammycook@gmail.com',
#  'gopal.ramasammycook@gmail.com',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
#  'david.horwitz@uct.ac.za',
# ...

# %%
#Q9) in above lst , there are repeated emails are there create unique email list
email_list=[]
for email in emails:
    if email not in email_list:
        email_list.append(email)
print(len(email_list))
# Out:
# 11

# %%
email_list=[]
[email_list.append(email) for email in emails if email not in email_list]
print(email_list)
# Out:
# ['stephen.marquard@uct.ac.za', 'louis@media.berkeley.edu', 'zqian@umich.edu', 'rjlowe@iupui.edu', 'cwen@iupui.edu', 'gsilver@umich.edu', 'wagnermr@iupui.edu', 'antranig@caret.cam.ac.uk', 'gopal.ramasammycook@gmail.com', 'david.horwitz@uct.ac.za', 'ray@media.berkeley.edu']
