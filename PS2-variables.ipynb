# %% [markdown]
# ### Variables

# %%
- variables term vary
- you want to save some values at some place , that place is called variables
- variables and constant

# %%
number = 100   # 100 values is stored in variable called number
number         # so here number is a variable
# Out:
# 100

# %%
# so hare first number has 100
#         second number has 200
# number is changing its value
# thats why we are calling number as variables

# %% [markdown]
# **Rules to define variables**

# %%
#Upper case
NUMBER=300
NUMBER
# Out:
# 300

# %%
 #Lower case
number=400
number
# Out:
# 400

# %%
#combination of upper case and lower case
NUMber=500
NUMber
# Out:
# 500

# %%
#Combination of latters and number, number as suffix
number123=600
number123
# Out:
# 600

# %%
#Combination of latters and number, number as prefix
123number=700
123number
# Out:
#   Cell In[18], line 2
#     123number=700
#       ^
# SyntaxError: invalid decimal literal

# %%
#spl characters
number%=800
number%
# Out:
#   Cell In[19], line 3
#     number%
#            ^
# SyntaxError: invalid syntax

# %%
#underscore
number_=900
number_
# Out:
# 900

# %%
#keyword
if=200
if
# Out:
#   Cell In[22], line 2
#     if=200
#       ^
# SyntaxError: invalid syntax

# %%
sum=700 # sum is math operation
sum
# Out:
# 700

# %% [markdown]
# **NOTE**
#        sum is a math operation it will works
#        but do not use as variable

# %%
#space is not allowed
number one = 800
number one
# Out:
#   Cell In[24], line 2
#     number one = 800
#            ^
# SyntaxError: invalid syntax

# %%
number_one = 800
number_one
# Out:
# 800

# %%
_=200
_
# Out:
# 200

# %%
########### Basics ############
1) Basic syntax
2) Variables
3) python packeges information
4) Basic python code
5) Condition statements
6) Functions
7) Loop 

############ Level-2 ############
1) strings
2) list
3) dictionary
4) tuples ========== write up artical and tuples (selp study)
5) sets
6) file handling session

######### level-3 ##########
1) oops concept in python 
2) how to create your own packages
3) FLASK APPS
