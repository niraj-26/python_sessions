# %% [markdown]
# # Function

# %% [markdown]
# **C16**
# - without argumentes
# - if you are not mentioning any values inside the function bracket
# - called without arguments or with out parameters

# %%
def <function_name>():
    # code
# Out:
#   Cell In[3], line 1
#     def <function_name>():
#         ^
# SyntaxError: invalid syntax

# %%
# the output will not display untill unless you call the function

# %%
def neer():
    print("hello")

neer()   # here calling the function
# Out:
# hello

# %%
def avg():
    n=eval(input("enter a number"))
    m=eval(input("enter a number"))
    q=eval(input("enter a number"))
    avg=(n+m+q)/3
    print(f"the average of 3 numbers {n},{m},{q} is {avg}")
avg()
# Out:
# enter a number 4
# enter a number 6
# enter a number 0
# the average of 3 numbers 4,6,0 is 3.3333333333333335

# %%
def avg():
    try:
        n=eval(input("enter a number"))
        m=eval(input("enter a number"))
        q=eval(input("enter a number"))
        avg=(n+m+q)/3
        print(f"the average of 3 numbers {n},{m},{q} is {avg}")
    except Exception as e:
        print(e)
avg()
# Out:
# enter a number 56
# enter a number 67
# enter a number 34
# the average of 3 numbers 56,67,34 is 52.333333333333336

# %%
def avg():
    try:
        n=eval(input("enter a number"))
        m=eval(input("enter a number"))
        q=eval(input("enter a number"))
        avg=(n+m+q)/3
        print(f"the average of 3 numbers {n},{m},{q} is {avg}")
    except Exception as e:
        print(e)
avg()
# Out:
# enter a number 67
# enter a number 78
# enter a number 89
# the average of 3 numbers 67,78,89 is 78.0

# %%
def amount():
    try:
        bill_amount=eval(input("enter the bill amount:"))
        tip_amount=eval(input("enter the tip amount:"))
        total_bill=bill_amount+tip_amount
        print(f"Total Bill pay by the user {total_bill} ")
    except exception as e:
        print(e)
amount()
# Out:
# enter the bill amount: 4500
# enter the tip amount: 560
# Total Bill pay by the user 5060

# %%
import random          # packages always Should be on the top 
def num():
    try:
        num=random.randint(1,100)
        if num%2==0:
            print(f"the number {num} is even ")
        else:
            print(f"the number {num} is odd ")
    except exception as e:
        print(e)
num()
# Out:
# the number 51 is odd

# %%
import time
def add():
    n1=20
    n2=30
    print("addition",n1+n2)

def mul():
    n1=20
    n2=30               # in every function make new input
    print("multiplication",n1*n2)

def sub():
    n1=40
    n2=89
    print("sub",n1-n2)

print("anything remains")
time.sleep(2)
print("no")
time.sleep(1)
print("then call the function")
sub()
add()
mul()
# Out:
# anything remains
# no
# then call the function
# sub -49
# addition 50
# multiplication 600

# %% [markdown]
#  **with arguments**

# %%
def addition(n1,n2):
    add=n1+n2
    print(f"the addition of {n1} and {n2} is {add} ")
addition(20,30)
# Out:
# the addition of 20 and 30 is 50

# %%
def avg(n,m,q):
    avg=(n+m+q)/3
    print(f"the average of 3 numbers {n},{m},{q} is {avg}")
avg(20,30,40)
# Out:
# the average of 3 numbers 20,30,40 is 30.0

# %% [markdown]
# **C17**

# %%
def number(num):
    square=num*num
    print(f"the square of {num} is {square}:")
number(13)
# Out:
# the square of 13 is 169:

# %%
# step1
import random
def number(num):
    n=random.randint(1,20)
    if num==n:
        print("won")
    else:
        print("lost",n)
number(15)
# Out:
# lost 14

# %% [markdown]
# # **

# %%
#step2
import random
def number(value,num):        # here you give anything not depend in calling function 
                               # but you give 2 value if you need 2 value in calling function
    if value==num:
        print("won")
    else:
        print("lost",value)
number(random.randint(1,20),eval(input("enter the value:")))
# Out:
# enter the value: 8
# lost 7

# %%
#step3
import random
n=random.randint(1,20)
value=eval(input("enter a num:"))
def number(num):
    
    if num==n:
        print("won",n)
    else:
        print("lost",n)
number(value)
# Out:
# enter a num: 67
# lost 1

# %%
def salary(sal,tax):
    total_tax=sal*tax/100
    print(f"total tax is {total_tax}:")
salary(50000,5)
# Out:
# total tax is 2500.0:

# %% [markdown]
# **default argument**

# %%
def salary(sal,tax=10):
    total_tax=sal*tax/100
    print(f"total tax is {total_tax}:")
salary(50000)
# Out:
# total tax is 5000.0:

# %% [markdown]
# # C18

# %%
# default function
import math
def circle(r=20):
    a=round((math.pi)*r**2)
    print("the area of circle is",a)
circle()
# Out:
# the area of circle is 1257

# %%
#with out argument
def circle():
    r=eval(input("enter the radius of circle:"))
    A=round((math.pi)*r**2)
    print("the area of circle is",A)
circle()
# Out:
# enter the radius of circle: 20
# the area of circle is 1257

# %%
# with argument
def circle(r):
    a=round((math.pi)*r**2)
    print("the area of circle is",a)
circle(20)
# Out:
# the area of circle is 1257

# %%
# keyboard pass
import math
def circle(r):
    a=round((math.pi)*r**2)
    print("the area of circle is",a)
r=eval(input("enter the radius of circle:"))
circle(r)
# Out:
# enter the radius of circle: 20
# the area of circle is 1257

# %% [markdown]
# **Return**

# %%
import math
def circle():
    r=eval(input("enter the radius of circle:"))
    pi=math.pi
    A=round(pi*r**2)
    print("the area of circle is",A)
    return(pi,A)
pi,area=circle()
print(pi)
print(area)
# Out:
# enter the radius of circle: 20
# the area of circle is 1257
# 3.141592653589793
# 1257

# %%
def avg_sum(num1,num2,num3):
    sum=num1+num2+num3
    avg=sum/3
    print(f"the number {num1},{num2},{num3} of sum is {sum} and avg is {avg}:")
    return(sum,avg)
add,avg=avg_sum(11,22,33)
print(add,avg)
# Out:
# the number 11,22,33 of sum is 66 and avg is 22.0:
# 66 22.0

# %%
def biggest(n1,n2,n3):
    if n1>n2 and n1>n3:
        print(f"the biggest number is{n1}:")
        return(n1)
    elif n2>n3:
        print(f"the biggest number is {n2}:")
        return(n2)
    else:
        print(f"the biggest number is {n3}:")
        return(n3)
greater=biggest(20,50,60)
print(greater)
# Out:
# the biggest number is 60:
# 60

# %%
def avg_sum(num1,num2,num3):
    return(num1+num2+num3,num1+num2+num3/3)
add,avg=avg_sum(11,22,33)
print(add,avg)
# Out:
# 66 44.0

# %%
def add(a,b):
    return(a+b)
def sub(a,b):
    return(a-b)
def mul(a,b):
    return(a*b)
def div(a,b):
    return(a/b)

val_add=add(20,30)
val_sub=sub(90,70)
val_mul=mul(20,50)
val_div=div(90,40)
print(val_add,val_sub,val_mul,round(val_div,2))
# Out:
# 50 20 1000 2.25

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
add,sub,mul,div=aggregation(20,30)
print(add,sub,mul,round(div,2))
# Out:
# 50 -10 600 0.67

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
value=aggregation(20,30)
print(value)
# Out:
# (50, -10, 600, 0.6666666666666666)

# %%
def add(a,b):return(a+b)
def sub(a,b):return(a-b)
def mul(a,b):return(a*b)
def div(a,b):return(a/b)

val_add=add(20,30)
val_sub=sub(90,70)
val_mul=mul(20,50)
val_div=div(90,40)
print(val_add,val_sub,val_mul,round(val_div,2))
# Out:
# 50 20 1000 2.25

# %% [markdown]
# # C19

# %% [markdown]
# **local variables->
# - the variables provided inside the function
# - local variables values can not use outside the fuction
# - untill unless you return those values.**

# %% [markdown]
# **globle variables->the variables provided outside the function**

# %%
# globle
n1=20
n2=30
def addition(): # no need to provide inside the bracket
    # no need to mention
    add=n1+n2
    print(f"the addition of{n1} and {n2} is {add} ")
addition()
# Out:
# the addition of20 and 30 is 50

# %%
# local
def addition(): 
    n1=20
    n2=30
    add=n1+n2
    print(f"the addition of{n1} and {n2} is {add} ")
addition()
# Out:
# the addition of20 and 30 is 50

# %%
def avg_sum():
    num1=11
    num2=22
    num3=33
    sum=num1+num2+num3
    avg=sum/3
    print(f"the number {num1},{num2},{num3} of sum is {sum} and avg is {avg}:")
    return(sum,avg)
add,avg=avg_sum()
print(add,avg)
# Out:
# the number 11,22,33 of sum is 66 and avg is 22.0:
# 66 22.0

# %%
num1=11
num2=22
num3=33
def avg_sum():
    
    sum=num1+num2+num3
    avg=sum/3
    print(f"the number {num1},{num2},{num3} of sum is {sum} and avg is {avg}:")
    return(sum,avg)
add,avg=avg_sum()
print(add,avg)

#also use any othe function (condition ,loop)
# Out:
# the number 11,22,33 of sum is 66 and avg is 22.0:
# 66 22.0

# %% [markdown]
# **

# %%
n1=20
n2=30
def addition(): 
    n1=20
    n2=30
    add=n1+n2
    print(f"the addition of{n1} and {n2} is {add} ")
addition()
print(n1)
# Out:
# the addition of20 and 30 is 50
# 20

# %%
n1=20
n2=30
def addition(n1): 

    n2=30
    add=n1+n2
    print(f"the addition of{n1} and {n2} is {add} ")
addition(500)
print(n1)
# Out:
# the addition of500 and 30 is 530
# 20

# %%
n1=20
n2=30
def addition(n1=200): 
    
    n2=30
    add=n1+n2
    print(f"the addition of{n1} and {n2} is {add} ")
addition(300)
print(n1)
# Out:
# the addition of300 and 30 is 330
# 20

# %%
def value():
    num=30
    print(num1)
value()
print(num)
# Out:
# 11
# 20

# %%
def value():
    global num
    num=60
    print(num1)

value()
print(num)
# Out:
# 11
# 60

# %%
n_=10
def updated():
    n_=20
    n_=n_+100
    print("n_ value inside function is :",n_)
updated()
print(n_)
# Out:
# n_ value inside function is : 120
# 10

# %%
n_=10
def updated():
    global n_
    n_=20
    n_=n_+100
    print("n_ value inside function is :",n_)
updated()
print(n_)
# Out:
# n_ value inside function is : 120
# 120

# %% [markdown]
# **function in function**

# %%
def greet():
    print("hello")

def name():
    print("python")

greet()
name()
# Out:
# hello
# python

# %%
def greet():
    print("hello")

def name():
    print("python")
    greet()

name()
# Out:
# python
# hello

# %%
def greet():
    print("hello")
    name()
    
def name():
    print("python")
    greet()
greet()
name()

# %%
def greet():
    print("hello")
    name()
    
def name():
    print("python")
    greet()
greet()
print("--------------")

# %%
def greet():
    print("hello")
    name()

def name():
    print("python")

greet()
# Out:
# hello
# python

# %%
def fun():
    print('hello')
    print('python')
print("10,30")   # first this will coming 
fun()
# Out:
# 10,30
# hello
# python

# %%
def add(a,b):
    print(a+b)

def sub(a,b):
    print(a-b)

def mul(a,b):
    print(a*b)

def div(a,b):
    print(a/b)

def main():
    print("you need to provide some statements")
    print("if you want enter 1: addition operation will come:")
    print("if you want enter 2: substract operation will come:")
    print("if you want enter 3: multiple operation will come:")
    print("if you want enter 4: division operation will come:")
    operation=int(input("enter a number:"))
    a=eval(input("enter number:"))
    b=eval(input("enter a number:"))
    if operation==1:
        add(a,b)
    elif operation==2:
        sub(a,b)
    elif operation==3:
        mul(a,b)
    else: 
        div(a,b)
        
main ()
# Out:
# you need to provide some statements
# if you want enter 1: addition operation will come:
# if you want enter 2: substract operation will come:
# if you want enter 3: multiple operation will come:
# if you want enter 4: division operation will come:
# enter a number: 3
# enter number: 34
# enter a number: 67
# 2278

# %%
a=eval(input("enter number:"))
b=eval(input("enter a number:"))
def add():
    print(a+b)

def sub():
    print(a-b)

def mul():
    print(a*b)

def div():
    print(a/b)

def main():
    print("you need to provide some statements")
    print("if you want enter 1: addition operation will come:")
    print("if you want enter 2: substract operation will come:")
    print("if you want enter 3: multiple operation will come:")
    print("if you want enter 4: division operation will come:")
    operation=int(input("enter a number:"))
    
    if operation==1:
        add()
    elif operation==2:
        sub()
    elif operation==3:
        mul()
    else: 
        div()
        
main ()

# %% [markdown]
# # C20
