# %% [markdown]
# # Error

# %%
# 1-name_error..........variable is wrong
num1 = eval(input("enter a number1"))
num2=eval(input("enter a number2"))
add=num1+num3
print(add)
# Out:
# enter a number1 30
# enter a number2 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 num1 = eval(input("enter a number1"))
#       3 num2=eval(input("enter a number2"))
# ----> 4 add=num1+num3
#       5 print(add)
#
# NameError: name 'num3' is not defined

# %%
#2-SyntaxError  ............. "(" is not closed
num1 = eval(input("enter a number1")
num2=eval(input("enter a number2"))
add=num1+num2
print(add)
# Out:
#   Cell In[5], line 2
#     num1 = eval(input("enter a number1")
#                ^
# SyntaxError: '(' was never closed

# %%
#3- ZerodivisionError.............divided by 0
num1 = eval(input("enter a number1"))
num2=eval(input("enter a number2"))
add=num1/num2
print(add)
# Out:
# enter a number1 20
# enter a number2 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 num1 = eval(input("enter a number1"))
#       3 num2=eval(input("enter a number2"))
# ----> 4 add=num1/num2
#       5 print(add)
#
# ZeroDivisionError: division by zero

# %%
#4-TypeError.....division a string into int or float
num1 =input("enter a number1")
num2=eval(input("enter a number2"))
add=num1+num2
print(add)
# Out:
# enter a number1 python
# enter a number2 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 num1 =input("enter a number1")
#       3 num2=eval(input("enter a number2"))
# ----> 4 add=num1+num2
#       5 print(add)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#5- SyntaxError......missing parentheses 
num1 = eval(input("enter a number1"))
num2=eval(input("enter a number2"))
add=num1+num2
print add

# %%
#6-NameError........name ..... is not defined
num1 = eval(input("enter a number1"))
num2=eval(input("enter a number2"))
add=num1+num2
Print(add)  # captal P is not defined and also black color is variable
# Out:
# enter a number1 30
# enter a number2 29
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 num2=eval(input("enter a number2"))
#       4 add=num1+num2
# ----> 5 Print(add)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# # Exception handling

# %% [markdown]
# $try$-$except$
# - there are two blocks
# - one try block
# - another is exception block
# - your code will be there in try block
# - error capture will happens in except block
# - indentation: space
# - red : space/indentation not maintained properly
# - : is there,then indentation will be there

# %%
try:
    num1=10
    num2=20
    num3=20
    add=num1+num2+num3
    print(add)
    
except:
    print("error is there,check code")
# Out:
# 50

# %%
try:
    num1=10
    num2=0
    num3=20
    add=num1/num2
    print(add)
    
except:
    print("error is there,check code")
# Out:
# error is there,check code

# %%
try:
    num1 = eval(input("enter number1:"))
    num2 = eval(input("enter number2:"))
    num3 = eval(input("enter number3:"))
    average=(num1+num2+num3)/3
    print("the avarage of {},{} and is{}". format(num1,num2,num3,average))

except:
    print("check the code")
# Out:
# enter number1: 30
# enter number2: 50
# enter number3: 10
# the avarage of 30,50 and is10

# %%
try:
    num1 = eval(input("enter number1:"))
    num2 = eval(input("enter number2:"))
    num3 = eval(input("enter number3:"))
    average=(num1+num2+num3333)/3
    print("the avarage of {},{} and is{}". format(num1,num2,num3,average))

except:
    print("check the code")
# Out:
# enter number1: 30
# enter number2: 50
# enter number3: 10
# check the code

# %%
try:
    num1 = eval(input("enter number1:"))
    num2 = eval(input("enter number2:"))
    num3 = eval(input("enter number3:"))
    average=(num1+num2+num3333)/3
    print("the avarage of {},{} and is{}". format(num1,num2,num3,average))

except Exception as e:
    print(e)

# error-1 = name error
# Out:
# enter number1: 20
# enter number2: 40
# enter number3: 60
# name 'num3333' is not defined

# %%
try:
    num1 = eval(input("enter number1:"))
    num2 = eval(input("enter number2:"))
    num3 = eval(input("enter number3:"))
    average=(num1+num2+num3333)/0
    print("the avarage of {},{} and is{}". format(num1,num2,num3,average))

except Exception as neer:
    print(neer)
# Out:
# enter number1: 30
# enter number2: 20
# enter number3: 50
# name 'num3333' is not defined

# %%
# wap ask the user enter a number and find the square of the number

num = eval(input("enter a number:"))
print("the square of {} is {} ".format(num,num*num))
# Out:
# enter a number: 10
# the square of 10 is 100

# %%
try:
    num = eval(input("enter a number:"))
    print("the square of {} is {} ".format(num,num*num))
except Exception as e:
    print(e)
# Out:
# enter a number: 10
# the square of 10 is 100

# %%
try:
    num = eval(input("enter a number:"))
    print("the square of {} is {} ".format(num25,num*num))
except Exception as e:
    print(e)
# Out:
# enter a number: 50
# name 'num25' is not defined

# %%
import sys
sys.exc_info()
# Out:
# (None, None, None)

# %%
try:
    num = eval(input("enter a number:"))
    print("the square of {} is {} ".format(num25,num*num))
except Exception as e:
    print("hai")
    print(e)
    print("hello")
# Out:
# enter a number: 30
# hai
# name 'num25' is not defined
# hello

# %% [markdown]
# - if your code is with out error, try block will execute
# - if your code has errors,it will redirect to except block
# - what ever you written inside except block that will run
# - try and exception is together
# - ones try and exceptions are complete,it try to look any others lines of code are there

# %%
try:
    num = eval(input("enter a number:"))
    print("the square of {} is {} ".format(num25,num*num))
print("out")
except Exception as e:
    print("hai")
    print(e)
    print("hello")
# Out:
#   Cell In[7], line 4
#     print("out")
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
print("wdeie")

try:
    num = eval(input("enter a number:"))
    print("the square of {} is {} ".format(num25,num*num))
except Exception as e:
    print("hai")
    print(e)
    print("hello")
# Out:
# wdeie
# enter a number: 120
# hai
# name 'num25' is not defined
# hello

# %%
try:
    num = eval(input("enter a number:"))
    print("the square of {} is {} ".format(num25,num*num))
except Exception as e:
    print("hai")
    print(e)
    print("hello")

print("neeraj")
# Out:
# enter a number: 78
# hai
# name 'num25' is not defined
# hello
# neeraj
